# %%
# %matplotlib inline
# %matplotlib notebook # is an interactive version

# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import os
import glob
import skimage

# %%
mpl.rcParams['figure.figsize'] = (6, 4)
mpl.rcParams['figure.dpi'] = 150

# %%
DATA_FOLDER = os.path.join('C:\\', 'Users', 'gt8mar', 'patiente')
print(DATA_FOLDER)
# Out:
# C:\Users\gt8mar\patiente

# %%
file_list = glob.glob(os.path.join(DATA_FOLDER, 'Basler_acA1300-200um__23253950__20200219_115028802_*.tiff'))
print(file_list[0])
# Out:
# C:\Users\gt8mar\patiente\Basler_acA1300-200um__23253950__20200219_115028802_1.tiff

# %%
data = np.dstack([skimage.external.tifffile.imread(x) for x in file_list[:5]])
print(data.shape)
print(data.dtype)
# Out:
# (579, 1280, 5)
# uint16

# %%
plt.hist(data.flatten(),
         bins=np.arange(40000, 41000));

# %%
plt.imshow(data[:,:,0], cmap='gray')

# %%
plt.imshow(data[:,:,1], cmap='gray')

# %%
data_flatten = data.transpose(2,0,1).reshape(data.shape[0]*data.shape[2], data.shape[1])
data_flatten.shape
# Out:
# (2895, 1280)

# %%
plt.figure(figsize=(6, 12))
plt.imshow(data_flatten, cmap='gray')
